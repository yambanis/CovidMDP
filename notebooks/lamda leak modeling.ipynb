# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x): return .01 - .01/(0.3+x)

# %%
def lambda_leak_value(x, exp=3, max_value=0.05): return (x**exp)*max_value
x = np.linspace(0, 1, 1000)
plt.plot(x, lambda_leak(x))

# %%
lambda_leak(.6)
# Out:
# 0.010799999999999999
